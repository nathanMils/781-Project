# %%
import pandas as pd
from pathlib import Path
from urllib.parse import urlparse
import re
import whois
import ssl
import socket
from datetime import datetime
import tldextract
from urllib.parse import urlparse, urljoin
import dns.resolver

# %%
DATA_DIR = Path('../data')
PHISH_DIR = DATA_DIR / 'phishtank'
LEGIT_DIR = DATA_DIR / 'common_crawl'
PROCESSED_DIR = DATA_DIR / 'processed'
PHISH_DATA = PHISH_DIR / 'collected_data.csv'
LEGIT_DATA = LEGIT_DIR / 'collected_data.csv'

# %% [markdown]
# # ADDRESS BAR FEATURES

# %%
top_phishing_tlds = [
    # Cheap and Open TLDs
    ".xyz", ".top", ".club", ".online", ".shop", ".site", ".vip", ".buzz",

    # Freenom TLDs (Free Domains)
    ".tk", ".ml", ".ga", ".cf", ".gq",

    # Geographic and Niche TLDs less commonly used for legitimate purposes
    ".ly", ".to", ".ru", ".cn", ".su"
]

def is_statistical_report(url):
    """Determines if the URL has a suspicious statistical report based on phishing domains or IPs."""
    ext = tldextract.extract(url)
    
    if ext.suffix in top_phishing_tlds:
        return -1  # Phishing
    
    return 1 

def core_domain(url):
    """Normalize the URL by extracting only the core domain using tldextract."""
    extracted = tldextract.extract(url)
    core_domain = f"{extracted.domain}.{extracted.suffix}"
    return core_domain

def domain_name(url):
    """Normalize the URL by extracting only the domain name using tldextract."""
    extracted = tldextract.extract(url)
    return extracted.domain

def lower_case(url):
    """Normalize the URL by converting it to lowercase."""
    return url.lower()

def is_having_ip(url):
    """Determines if the URL has an IP address."""
    parsed_url = urlparse(url)
    domain = parsed_url.netloc.lower().split(':')[0]  # Remove port if present
    
    ipv4_pattern = r"^(\d{1,3}\.){3}\d{1,3}$"
    hex_ip_pattern = r"^0x[0-9a-fA-F]{1,2}(\.0x[0-9a-fA-F]{1,2}){3}$"

    if re.match(ipv4_pattern, domain):
        return -1
    
    elif re.match(hex_ip_pattern, domain):
        hex_parts = domain.split('.')
        decimal_parts = []
        for part in hex_parts:
            decimal_parts.append(str(int(part, 16)))
        return -1
    
    return 1

def is_url_long(url):
    """Determines if the URL length is suspicious or phishing based on length."""
    url_length = len(url)
    
    if url_length < 54:
        return 1  # Legitimate
    elif 54 <= url_length <= 75:
        return 0  # Suspicious
    else:
        return -1  # Phishing
    
url_shortening_services = [
    "tinyurl.com", "bit.ly", "t.co", "goo.gl", "is.gd", "buff.ly",
    "adf.ly", "ow.ly", "bit.do", "cutt.ly", "shorte.st", "clck.ru",
    "tiny.cc", "tr.im", "x.co", "soo.gd", "s2r.co", "bl.ink", "mcaf.ee",
    "urlz.fr", "shorturl.at"
]
def is_shortening_service(url):
    """Determines if the URL uses a URL shortening service."""
    core = core_domain(url)
    if core in url_shortening_services:
        return -1
    return 1

def is_double(url):
    """Determines if the URL redirects using '//'."""
    parsed_url = urlparse(url)
    if parsed_url.scheme == "http":
        limit_position = 6
    elif parsed_url.scheme == "https":
        limit_position = 7
    else:
        return 1

    last_occurrence_index = url.rfind("//")

    if last_occurrence_index > limit_position:
        return -1
    else:
        return 1
    
    
    
def is_having_sub_domain(url):
    """Classifies a URL based on the number of subdomains."""
    ext = tldextract.extract(url)
    subdomain = ext.subdomain
    num_subdomains = len(subdomain.split('.')) if subdomain else 0
    
    if num_subdomains == 0:
        return 1  # Legitimate
    elif num_subdomains == 1:
        return 1  # Legitimate
    elif num_subdomains == 2:
        return 0  # Suspicious
    else:
        return -1

def is_dns_record(url, timeout=5):
    """Check if the domain or subdomain has DNS records."""
    ext = tldextract.extract(url)
    domain = f"{ext.domain}.{ext.suffix}"
    
    resolver = dns.resolver.Resolver()
    resolver.timeout = timeout
    resolver.lifetime = timeout  # Set a timeout for the entire resolution process
    
    try:
        a_records = resolver.resolve(domain, 'A')
        if a_records:
            print(f"A records: {a_records}")
            return 1
    except dns.resolver.NoAnswer:
        print("No A records")
    except dns.resolver.NXDOMAIN:
        print("NXDOMAIN")
        return -1
    except dns.exception.Timeout:
        print("DNS query timed out for A records")
        return -1
    except dns.resolver.NoNameservers:
        print("No nameservers available to resolve the domain")
        return -1
    
    try:
        aaaa_records = resolver.resolve(domain, 'AAAA')
        if aaaa_records:
            print(f"AAAA records: {aaaa_records}")
            return 1
    except dns.resolver.NoAnswer:
        print("No AAAA records")
    except dns.resolver.NXDOMAIN:
        print("NXDOMAIN")
        return -1
    except dns.exception.Timeout:
        print("DNS query timed out for AAAA records")
        return -1
    except dns.resolver.NoNameservers:
        print("No nameservers available to resolve the domain")
        return -1
    
    return -1

def is_abnormal_url(url):
    """Determines if the URL is abnormal."""
    ext = tldextract.extract(url)
    host_name = ext.domain + '.' + ext.suffix
    w = whois.whois(url)
    if w and 'domain_name' in w:
        domain_names = w['domain_name']
        print(f"Domain names: {domain_names}")
        if isinstance(domain_names, list):
            for domain in domain_names:
                if host_name.lower() == domain.lower():
                    return 1
        elif isinstance(domain_names, str):
            if host_name.lower() == domain_names.lower():
                return 1
    return -1

# %%
df_phish = pd.read_csv(PHISH_DATA)

for index, row in df_phish.iterrows():
    if df_phish.loc[index, 'shortining_service'] != is_shortening_service(df_phish.loc[index, 'website_url']):
        print(f"Shortening service mismatch at index {index}.")
        print(f"{df_phish.loc[index,'website_url']}, {df_phish.loc[index, 'shortining_service']}, {is_shortening_service(df_phish.loc[index, 'website_url'])}")
# Out:
# Shortening service mismatch at index 118.
# https://urlz.fr/t2Je, 1, -1
# Shortening service mismatch at index 119.
# https://urlz.fr/t2HL, 1, -1
# Shortening service mismatch at index 125.
# https://urlz.fr/t31X, 1, -1
# Shortening service mismatch at index 126.
# https://urlz.fr/t2Je, 1, -1
# Shortening service mismatch at index 127.
# https://urlz.fr/t2HL, 1, -1
# Shortening service mismatch at index 130.
# https://urlz.fr/t30u, 1, -1
# Shortening service mismatch at index 132.
# https://urlz.fr/t2Z6, 1, -1
# Shortening service mismatch at index 133.
# https://urlz.fr/t2U4, 1, -1
# Shortening service mismatch at index 135.
# https://urlz.fr/t2DP, 1, -1
# Shortening service mismatch at index 157.
# https://urlz.fr/t2Je, 1, -1
# Shortening service mismatch at index 158.
# https://urlz.fr/t2HL, 1, -1
# Shortening service mismatch at index 446.
# https://urlz.fr/t1Vh, 1, -1
# Shortening service mismatch at index 448.
# https://urlz.fr/t2Nq, 1, -1
# Shortening service mismatch at index 507.
# https://shorturl.at/AINF5?JHQ=rbtFZaq, 1, -1
# Shortening service mismatch at index 510.
# https://shorturl.at/6ft3m?Wh=Trdf6, 1, -1
# Shortening service mismatch at index 514.
# https://shorturl.at/19OlI?PZ=yWj8fe, 1, -1
# Shortening service mismatch at index 1242.
# https://shorturl.at/ox06H?UMu=P9vhMmiK, 1, -1
# Shortening service mismatch at index 1245.
# https://urlz.fr/t1lP, 1, -1
# Shortening service mismatch at index 1246.
# https://urlz.fr/t0JN, 1, -1
# Shortening service mismatch at index 1248.
# https://urlz.fr/sZy8, 1, -1
# Shortening service mismatch at index 1250.
# https://urlz.fr/t1tO, 1, -1
# Shortening service mismatch at index 1252.
# https://urlz.fr/t1sZ, 1, -1
# Shortening service mismatch at index 1253.
# https://urlz.fr/sVhq, 1, -1
# Shortening service mismatch at index 1344.
# https://urlz.fr/t0Yp, 1, -1
# Shortening service mismatch at index 1618.
# https://shorturl.at/PEdOz?lt=7pG4cb, 1, -1
# Shortening service mismatch at index 1619.
# https://shorturl.at/bOUPL?BUI=nZNvE, 1, -1
# Shortening service mismatch at index 1620.
# https://www.shorturl.at/vi08R?Sdi=peOXnI, 1, -1
# Shortening service mismatch at index 1621.
# https://www.shorturl.at/rEYqN?tA=gibAnc, 1, -1
# Shortening service mismatch at index 1683.
# https://www.shorturl.at/jqxtN, 1, -1
# Shortening service mismatch at index 1684.
# https://shorturl.at/jqxtN, 1, -1
# Shortening service mismatch at index 1693.
# https://shorturl.at/NxPeJ, 1, -1
# Shortening service mismatch at index 1694.
# https://www.shorturl.at/NxPeJ, 1, -1
# Shortening service mismatch at index 1786.
# http://metamask-wallett.blogspot.co.at/, -1, 1
# Shortening service mismatch at index 1792.
# https://dhl-tracking-au.blogspot.com.uy/, -1, 1
# Shortening service mismatch at index 1809.
# http://spotifyclonewithorpa.freewebhostmost.com/, -1, 1
# Shortening service mismatch at index 1832.
# http://myspotifymusic.freewebhostmost.com/, -1, 1
# Shortening service mismatch at index 1838.
# http://spotifystarc.freewebhostmost.com/, -1, 1
# Shortening service mismatch at index 1879.
# http://bet958x.com/, -1, 1
# Shortening service mismatch at index 1941.
# http://toknepocket.com/, -1, 1
# Shortening service mismatch at index 1986.
# https://m.momabout.com/, -1, 1
# Shortening service mismatch at index 2016.
# http://pubgmobile.freewebhostmost.com/, -1, 1
# Shortening service mismatch at index 2018.
# https://m.ceair-st.com/, -1, 1
# Shortening service mismatch at index 2051.
# http://trackyourpackageusps.blogspot.com.au/, -1, 1
# Shortening service mismatch at index 2055.
# http://metamask-wallett.blogspot.co.ke/, -1, 1
# Shortening service mismatch at index 2062.
# http://accounts.vps3.ww2x.com/, -1, 1
# Shortening service mismatch at index 2082.
# https://www.workspieinternet.com/, -1, 1
# Shortening service mismatch at index 2191.
# http://spotify-mohit.freewebhostmost.com/, -1, 1
# Shortening service mismatch at index 2320.
# http://m.cokkit.com/, -1, 1
# Shortening service mismatch at index 2326.
# http://commonsnuofirst.com/, -1, 1
# Shortening service mismatch at index 2339.
# http://m.serenitycontent.com/, -1, 1
# Shortening service mismatch at index 2347.
# http://m.commonsnuofirst.com/, -1, 1

# %%
for index, row in df_phish.iterrows():
    if df_phish.loc[index, 'url_length'] != is_url_long(df_phish.loc[index, 'website_url']):
        print(f"Double slash mismatch at index {index}.")
        print(f"{df_phish.loc[index,'website_url']}, {df_phish.loc[index, 'url_length']}, {is_url_long(df_phish.loc[index, 'website_url'])}")
# Out:
# Double slash mismatch at index 3.
# https://web13319.cweb06.gamingcontrol.de/ch/chpost/N/swiss_de/, -1, 0
# Double slash mismatch at index 30.
# https://compliance-page-issu.d13z0rbu5zhsxy.amplifyapp.com/, -1, 0
# Double slash mismatch at index 31.
# https://compliance-page-issu.d13z0rbu5zhsxy.amplifyapp.com/, -1, 0
# Double slash mismatch at index 38.
# https://microsoftoffice365onedrivedocument.weebly.com/, -1, 0
# Double slash mismatch at index 67.
# https://intermediate-peppermint-blackbird.glitch.me/hostlink.html, -1, 0
# Double slash mismatch at index 87.
# https://4215465tygfgarcfdens655665df56568767.weeblysite.com/, -1, 0
# Double slash mismatch at index 93.
# https://05456et3454svdf04b8fd5ab27b1be5e7b51d9d8146566.weeblysite.com/, -1, 0
# Double slash mismatch at index 148.
# https://swisspass-ch-remov.codeanyapp.com/aa/d/sign.php, -1, 0
# Double slash mismatch at index 149.
# https://pub-c75b5893124e4c2cb9233f0097f1d214.r2.dev/freshdocu%25%5E.html, -1, 0
# Double slash mismatch at index 150.
# https://pub-b4b4dc12227642af8ca5dc2dabd9d8e0.r2.dev/index.html, -1, 0
# Double slash mismatch at index 151.
# https://pub-5d464b03c9cb41c5971cfcbda02b7af2.r2.dev/freshdocu%25%5E.html, -1, 0
# Double slash mismatch at index 152.
# https://pub-3d0558b7902a4c459f6f56e0d666a033.r2.dev/index.html, -1, 0
# Double slash mismatch at index 225.
# https://fkm.f19.mytemp.website/fkmf19/sos/att/atts/att-detail-Adjust/, -1, 0
# Double slash mismatch at index 283.
# https://bingkas-2024-program-bantuan-ewallet0.88nur.com/log-masuk.php, -1, 0
# Double slash mismatch at index 365.
# https://trimnitreunverstersborrtruniteyrnosent.weebly.com/, -1, 0
# Double slash mismatch at index 366.
# https://atmailupdateformeupdaterdzxtdinfomailacct.weebly.com/, -1, 0
# Double slash mismatch at index 400.
# https://spotify.information-premium.com/captcha/captcha.php, -1, 0
# Double slash mismatch at index 403.
# https://share.hsforms.com/1bEUlpBcPRv2a3djJam6pYQsle9i, -1, 0
# Double slash mismatch at index 405.
# https://reviews-mail.d8s3qhcw1sku1.amplifyapp.com/#redacted@abuse.ionos.com, -1, 0
# Double slash mismatch at index 406.
# https://zhulihong12.github.io/Letsakeit.github.io/IONOS.html, -1, 0
# Double slash mismatch at index 422.
# https://weblogaccess-secureyouraccount-secureyo.webflow.io/, -1, 0
# Double slash mismatch at index 436.
# https://pub-2622fe2e06384cde8d12606cf16fb37c.r2.dev/cggg.html, -1, 0
# Double slash mismatch at index 521.
# https://pub-eeca398397354ff0bda3a8a33917339d.r2.dev/index.html, -1, 0
# Double slash mismatch at index 522.
# https://pub-573e81523d8b40f6a34d09ebb36c28e3.r2.dev/srt1.html, -1, 0
# Double slash mismatch at index 523.
# https://pub-50ca71577145447e96b69b604712ce22.r2.dev/index.html, -1, 0
# Double slash mismatch at index 524.
# https://pub-4315e7deddae4ebdbb2ebed9dfafbd05.r2.dev/index.html, -1, 0
# Double slash mismatch at index 525.
# https://pub-364ea8788b684a76867bee81a5b962c3.r2.dev/index.html, -1, 0
# Double slash mismatch at index 526.
# https://pub-21241eccbf1943f3bf0dc9aa678811f9.r2.dev/index.html, -1, 0
# Double slash mismatch at index 528.
# https://pub-fedc6dbd39304234a435b4707f489b31.r2.dev/polofreshlink.html, -1, 0
# Double slash mismatch at index 529.
# https://pub-b3befb2964a34a98b6428be4b0de0c9a.r2.dev/0nedrivedoc.html, -1, 0
# Double slash mismatch at index 530.
# https://pub-8bb98d0f8c5545db91601a18f254694e.r2.dev/0nedrivedoc.html, -1, 0
# Double slash mismatch at index 531.
# https://pub-4c9fa959e5ca4ed987adf66cfeeb3871.r2.dev/index.html, -1, 0
# Double slash mismatch at index 532.
# https://pub-4b4033bb2a9d4fd4b0ee4191dfd5c1d7.r2.dev/alt_type.html, -1, 0
# Double slash mismatch at index 533.
# https://pub-36c871205f3f4c5a92bf29b99a4b63dc.r2.dev/0nedrivedoc.html, -1, 0
# Double slash mismatch at index 541.
# https://sites.google.com/view/honshyjaghansssssss/home., -1, 0
# Double slash mismatch at index 552.
# https://spotify.portail-premium.com/captcha/captcha.php, -1, 0
# Double slash mismatch at index 571.
# https://dsp2-cledigitale.com/index2.php?redirection=login, -1, 0
# Double slash mismatch at index 579.
# https://gt191hpxcw.z8.web.core.windows.net/?hash=roque_wrs@hotmail.com, -1, 0
# Double slash mismatch at index 584.
# https://share.hsforms.com/1fmVwsQe0QnuGrA0JD8UmSwsnhl9, -1, 0
# Double slash mismatch at index 940.
# https://olx-pl.ycesurti.shop/payment/fb5d9beab639/millennium, -1, 0
# Double slash mismatch at index 951.
# https://olx-pl.filabrod.shop/payment/fb5d9beab639/millennium, -1, 0
# Double slash mismatch at index 1108.
# https://currentlymailiinbocxsejbkthdhcontadminseldnkcureddde.weebly.com/, -1, 0
# Double slash mismatch at index 1124.
# https://xhet.urj7z9q.com/EajOvOEBUFfP-mUx6d9kOCqrrWPg/, -1, 0
# Double slash mismatch at index 1254.
# https://pub-8b01452faac14401bae5354aefac3154.r2.dev/index.html, -1, 0
# Double slash mismatch at index 1255.
# https://pub-723511771ffe4b92a98f802d1f9591ae.r2.dev/index.html, -1, 0
# Double slash mismatch at index 1256.
# https://pub-564ba8b7c5cf4d46b9dbdef98c6b4b45.r2.dev/index.html, -1, 0
# Double slash mismatch at index 1257.
# https://pub-52902287106c437f9ba78eebec6913f5.r2.dev/index.html, -1, 0
# Double slash mismatch at index 1260.
# https://pub-9f8d20703c0b41dc8e0a41f1a5e47d9f.r2.dev/csuindex.html, -1, 0
# Double slash mismatch at index 1261.
# https://pub-b84f546dc50a484fbf6595e39dd3c3e8.r2.dev/index.html, -1, 0
# Double slash mismatch at index 1262.
# https://pub-ae7968dde7a149698eb2811aa7e6ed61.r2.dev/blobbofa.html, -1, 0
# Double slash mismatch at index 1266.
# https://sites.google.com/view/ggfghhjui/home?authuser=3, -1, 0
# Double slash mismatch at index 1574.
# https://share.hsforms.com/1l8KmB2eyRNy2N5anXqIw5wsle9i, -1, 0
# Double slash mismatch at index 1577.
# https://share.hsforms.com/1hzNSdc7PQ7G3SXsQ1dFbhAsmw2v, -1, 0
# Double slash mismatch at index 1623.
# https://pub-d30df380dd394bc793feaf774812cca9.r2.dev/doc_start.html, -1, 0
# Double slash mismatch at index 1659.
# https://signw3u9cn1mtj.159-65-163-57.cprapid.com//?gfas1, -1, 0
# Double slash mismatch at index 1663.
# https://matthevvpalm1988.activehosted.com/admin/archived_user.php, -1, 0
# Double slash mismatch at index 1675.
# https://www.magichealthpoint.com/wp-includes/tmp/16shop/error.html, -1, 0
# Double slash mismatch at index 1690.
# https://yarapainting.com.au/backup/wp-includes/css/hub/, -1, 0
# Double slash mismatch at index 1696.
# http://bingkas-programbantuan-ewallet-2024.xdbng.com/log-masuk.php, -1, 0
# Double slash mismatch at index 1697.
# https://bingkasprogrambantuan2024.xdbng.com/log-masuk.php, -1, 0
# Double slash mismatch at index 1698.
# http://connectpresale.vercel.app/walletpage/walletpage.html, -1, 0
# Double slash mismatch at index 1699.
# https://connectpresale.vercel.app/walletpage/walletpage.html, -1, 0
# Double slash mismatch at index 1700.
# https://pub-393d86087abc4dd48ed80206558e9911.r2.dev/viewdocument.html, -1, 0
# Double slash mismatch at index 1702.
# https://malaysamadani2024-gov-my.vercel.app/login1.html, -1, 0
# Double slash mismatch at index 1722.
# http://hello-world-nameless-bonus-9f98.raradag325.workers.dev/, -1, 0
# Double slash mismatch at index 1817.
# http://sf-fallersleben.de/wp-content/template/gateway/a60d31d556/, -1, 0
# Double slash mismatch at index 1887.
# http://updatedemailservicenowneededforbenefit.weebly.com/, -1, 0
# Double slash mismatch at index 1888.
# http://pub-f299ed5a53554671a7c61c793888b7ad.r2.dev/index.html, -1, 0
# Double slash mismatch at index 1891.
# http://pub-cd60dd802e1d493db03ad631609f8a2e.r2.dev/index.html, -1, 0
# Double slash mismatch at index 1893.
# http://bdcoraf.cluster029.hosting.ovh.net/Authentication, -1, 0
# Double slash mismatch at index 1894.
# http://pub-3f84de9aa4f04824a3cf79d4adea59cb.r2.dev/index.html, -1, 0
# Double slash mismatch at index 1899.
# http://pub-8e315825f4c1475c9f81d812a0ec1d22.r2.dev/index.html, -1, 0
# Double slash mismatch at index 1913.
# http://y-pg2-gsivuwhet873v2323t34t34v.knightangel-1.workers.dev/, -1, 0
# Double slash mismatch at index 1928.
# http://pub-845232413d77493aa1b626f5186dadae.r2.dev/index.html, -1, 0
# Double slash mismatch at index 1930.
# https://1stinvestor-us.mubasher.info/sobb/customer_center/user-036934, -1, 0
# Double slash mismatch at index 1931.
# https://1stinvestor-us.mubasher.info/sobb/customer_center/user-283591/, -1, 0
# Double slash mismatch at index 1951.
# https://1stinvestor-us.mubasher.info/sobb/customer_center/user-987083/, -1, 0
# Double slash mismatch at index 1953.
# https://1stinvestor-us.mubasher.info/sobb/customer_center/user-745774, -1, 0
# Double slash mismatch at index 1954.
# https://1stinvestor-us.mubasher.info/sobb/customer_center/user-003447/, -1, 0
# Double slash mismatch at index 1955.
# https://1stinvestor-us.mubasher.info/sobb/customer_center/user-950987/, -1, 0
# Double slash mismatch at index 1996.
# http://walletconnnect-deeplink-prompt-issue.vercel.app/, -1, 0
# Double slash mismatch at index 2015.
# http://compliance-account-review.d29u2v648ez7nd.amplifyapp.com/index.html, -1, 0
# Double slash mismatch at index 2024.
# https://1stinvestor-us.mubasher.info/sobb/customer_center/user-168160/, -1, 0
# Double slash mismatch at index 2043.
# http://66a10966b6b74235c06a61f5--amazon-miko-clon.netlify.app/, -1, 0
# Double slash mismatch at index 2102.
# http://interface-git-judo-routing-params-uniswap.vercel.app/, -1, 0
# Double slash mismatch at index 2138.
# https://pub-cd9d61c0fef041afa74e9cdbabfde444.r2.dev/AT%26TYA.html, -1, 0
# Double slash mismatch at index 2166.
# https://pub-e626509332fd4379acd83c32eac7a8a6.r2.dev/index.html, -1, 0
# Double slash mismatch at index 2182.
# http://facebook-clone-with-react-and-bootstrap.vercel.app/, -1, 0
# Double slash mismatch at index 2245.
# http://netflix-landing-page-clone-felomondis-projects.vercel.app/, -1, 0
# Double slash mismatch at index 2266.
# http://proxy-discord.jeemoo.com/application-directory/282859044593598464/, -1, 0
# Double slash mismatch at index 2275.
# https://fbmailsystem.com/case-true/606967319425038/form/, -1, 0
# Double slash mismatch at index 2286.
# https://www.dailycontestportal.shop/africa/cm/orange-box-1/fr-1.php, -1, 0
# Double slash mismatch at index 2296.
# https://1stinvestor-us.mubasher.info/sobb/customer_center/user-352723/, -1, 0
# Double slash mismatch at index 2311.
# https://gokhfhlfwpyb.top/ccbca3b04cb34292af328aabb47469f4, -1, 0
# Double slash mismatch at index 2315.
# https://netflix-landing-page-clone-git-main-felomondis-projects.vercel.app/, -1, 0
# Double slash mismatch at index 2376.
# https://pub-1ce9e7a22bad4d9e82b69b2884dabbd9.r2.dev/index.html, -1, 0
# Double slash mismatch at index 2377.
# https://pub-12c3834cbc02478eae1d5a41806cea0b.r2.dev/index.html, -1, 0
# Double slash mismatch at index 2378.
# https://pub-ec756871e9fc4365b71440c42a889801.r2.dev/index.html, -1, 0
# Double slash mismatch at index 2389.
# http://pub-238f01dd643c42f082469a85feccfb1c.r2.dev/nm.html, -1, 0
# Double slash mismatch at index 2390.
# http://pub-e9654273890b4c22aa104b8caa956c46.r2.dev/aviavtion.html, -1, 0
# Double slash mismatch at index 2391.
# http://pub-519769e9eb634616b1746c2018641d56.r2.dev/zanc.html, -1, 0
# Double slash mismatch at index 2392.
# http://pub-9a9bcfb9db254aa98e35aa4c9738d77f.r2.dev/nmj.html, -1, 0
# Double slash mismatch at index 2393.
# http://pub-60aa6c4fb16544cbbdd32ff4151d40f4.r2.dev/poknindex.html, -1, 0
# Double slash mismatch at index 2395.
# http://pub-b7fda1e0060f418199431736a36c9d53.r2.dev/bgvfrt.html, -1, 0
# Double slash mismatch at index 2401.
# http://pub-814357b3d980410c97b84c93e0f03986.r2.dev/serve.html, -1, 0
# Double slash mismatch at index 2402.
# http://pub-76b52a06819c45ecb532a96f9e4c584a.r2.dev/rstui.html, -1, 0
# Double slash mismatch at index 2403.
# http://pub-ac9a92367c8548748bc2819d5c738f15.r2.dev/nhyujm.html, -1, 0
# Double slash mismatch at index 2404.
# http://pub-7470c56c8ecb449d8fecae77c48a5c00.r2.dev/offes.html, -1, 0
# Double slash mismatch at index 2406.
# http://arafathrumman.github.io/facebook-login-signup-page/, -1, 0
# Double slash mismatch at index 2407.
# http://opencaassee10098654328.github.io/simplevrify/en/homes/, -1, 0
# Double slash mismatch at index 2432.
# https://pay8-2v-4wkfituj8-ekontetevi-gmailcom.vercel.app/, -1, 0
# Double slash mismatch at index 2435.
# https://pub-b2d0706696ae46748ded274185913628.r2.dev/index.html, -1, 0
# Double slash mismatch at index 2436.
# https://pub-33bffc01b8af423d8ee5acb2a32a9c79.r2.dev/index.html, -1, 0
# Double slash mismatch at index 2437.
# https://pub-54f10b2069bc4d7d830c4f30f712756d.r2.dev/index.html, -1, 0
# Double slash mismatch at index 2438.
# https://pub-08ccb1c9e7d64b1db82f179358ec2e35.r2.dev/index.html, -1, 0
# Double slash mismatch at index 2442.
# https://pub-8808e94b1a5c49dbb2a2e0829ec1562b.r2.dev/index.html, -1, 0
# Double slash mismatch at index 2443.
# https://pub-bff73fea0cd34ba18479407ee3443024.r2.dev/index.html, -1, 0
# Double slash mismatch at index 2444.
# https://pub-b3d85ff594e14e97a0327ee8329a4e7f.r2.dev/index.html, -1, 0
# Double slash mismatch at index 2445.
# https://pub-a6082f01e9074b539e48129bf3cb77f7.r2.dev/index.html, -1, 0
# Double slash mismatch at index 2446.
# https://pub-4768a5c939994ed2974419af3d97953d.r2.dev/index.html, -1, 0
# Double slash mismatch at index 2465.
# https://coinbase-com-72295.e6zacatfuk1jofbehm.workers.dev/, -1, 0
# Double slash mismatch at index 2468.
# http://overview-feedback-0104023402340032.di9lhpk6q7jtg.amplifyapp.com/, -1, 0

# %%
for index, row in df_phish.iterrows():
    if df_phish.loc[index, 'having_ip_address'] != is_having_ip(df_phish.loc[index, 'website_url']):
        print(f"Having IP mismatch at index {index}.")
        print(f"{df_phish.loc[index,'website_url']}, {df_phish.loc[index, 'having_ip_address']}, {is_having_ip(df_phish.loc[index, 'website_url'])}")

# %%
for index, row in df_phish.iterrows():
    if df_phish.loc[index, 'double_slash_redirecting'] != is_double(df_phish.loc[index, 'website_url']):
        print(f"Double slash mismatch at index {index}.")
        print(f"{df_phish.loc[index,'website_url']}, {df_phish.loc[index, 'double_slash_redirecting']}, {is_double(df_phish.loc[index, 'website_url'])}")

# %%
for index, row in df_phish.iterrows():
    if df_phish.loc[index, 'having_sub_domain'] != is_having_sub_domain(df_phish.loc[index, 'website_url']):
        print(f"Subdomain mismatch at index {index}.")
        print(f"{df_phish.loc[index,'website_url']}, {df_phish.loc[index, 'having_sub_domain']}, {is_having_sub_domain(df_phish.loc[index, 'website_url'])}")

# %%
df_valid = pd.read_csv(LEGIT_DATA)
# for index, row in df_phish.iterrows():
#     if df_phish.loc[index, 'abnormal_url'] != is_abnormal_url(df_phish.loc[index, 'website_url']):
#         print(f"Abnormal URL mismatch at index {index}.")
#         print(f"{df_phish.loc[index,'website_url']}, {df_phish.loc[index, 'abnormal_url']}, {is_abnormal_url(df_phish.loc[index, 'website_url'])}")

for index, row in df_valid.iterrows():
    if df_valid.loc[index, 'abnormal_url'] != is_abnormal_url(df_valid.loc[index, 'website_url']):
        print(f"Abnormal URL mismatch at index {index}.")
        print(f"{df_valid.loc[index,'website_url']}, {df_valid.loc[index, 'abnormal_url']}, {is_abnormal_url(df_valid.loc[index, 'website_url'])}")
# Out:
# Domain names: HOLLOWAYSOFLUDLOW.COM
# Domain names: airccse.org
# Domain names: ['LACARTOONS.COM', 'lacartoons.com']
# Domain names: ['PUERTOVALLARTAWALKINGTOURS.COM', 'puertovallartawalkingtours.com']
# Domain names: HOLMI.RU
# Domain names: partytwinkle.com.au
# Domain names: ['northernstar.nyc', 'NORTHERNSTAR.NYC']
# Domain names: ILLINOIS.EDU
# Domain names: myjobvacancies.co.ke
# Domain names: ['JAMARANEMA.COM', 'jamaranema.com']
# Domain names: ['ARMANI.COM', 'armani.com']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 8
#       2 # for index, row in df_phish.iterrows():
#       3 #     if df_phish.loc[index, 'abnormal_url'] != is_abnormal_url(df_phish.loc[index, 'website_url']):
#       4 #         print(f"Abnormal URL mismatch at index {index}.")
#       5 #         print(f"{df_phish.loc[index,'website_url']}, {df_phish.loc[index, 'abnormal_url']}, {is_abnormal_url(df_phish.loc[index, 'website_url'])}")
#       7 for index, row in df_valid.iterrows():
# ----> 8     if df_valid.loc[index, 'abnormal_url'] != is_abnormal_url(df_valid.loc[index, 'website_url']):
#       9         print(f"Abnormal URL mismatch at index {index}.")
#      10         print(f"{df_valid.loc[index,'website_url']}, {df_valid.loc[index, 'abnormal_url']}, {is_abnormal_url(df_valid.loc[index, 'website_url'])}")
#
# Cell In[11], line 163, in is_abnormal_url(url)
#     161 ext = tldextract.extract(url)
#     162 host_name = ext.domain + '.' + ext.suffix
# --> 163 w = whois.whois(url)
#     164 if w and 'domain_name' in w:
#     165     domain_names = w['domain_name']
#
# File c:\Users\natei\AppData\Local\pypoetry\Cache\virtualenvs\781-project-_wk9diy5-py3.11\Lib\site-packages\whois\__init__.py:46, in whois(url, command, flags, executable, inc_raw, quiet)
#      43 else:
#      44     # try builtin client
#      45     nic_client = NICClient()
# ---> 46     text = nic_client.whois_lookup(None, domain.encode("idna"), flags, quiet=quiet)
#      47 entry = WhoisEntry.load(domain, text)
#      48 if inc_raw:
#
# File c:\Users\natei\AppData\Local\pypoetry\Cache\virtualenvs\781-project-_wk9diy5-py3.11\Lib\site-packages\whois\whois.py:425, in NICClient.whois_lookup(self, options, query_arg, flags, quiet)
#     418     result = self.whois(
#     419         query_arg,
#     420         options["country"] + NICClient.QNICHOST_TAIL,
#     421         flags,
#     422         quiet=quiet,
#     423     )
#     424 elif self.use_qnichost:
# --> 425     nichost = self.choose_server(query_arg)
#     426     if nichost is not None:
#     427         result = self.whois(query_arg, nichost, flags, quiet=quiet)
#
# File c:\Users\natei\AppData\Local\pypoetry\Cache\virtualenvs\781-project-_wk9diy5-py3.11\Lib\site-packages\whois\whois.py:390, in NICClient.choose_server(self, domain)
#     388     return NICClient.SITE_HOST
#     389 else:
# --> 390     return self.findwhois_iana(tld)
#
# File c:\Users\natei\AppData\Local\pypoetry\Cache\virtualenvs\781-project-_wk9diy5-py3.11\Lib\site-packages\whois\whois.py:154, in NICClient.findwhois_iana(tld)
#     152 response = b""
#     153 while True:
# --> 154     d = s.recv(4096)
#     155     response += d
#     156     if not d:
#
# KeyboardInterrupt:

# %%
df_valid = pd.read_csv(LEGIT_DATA)

# %%
# for index, row in df_phish.iterrows():
#     if df_phish.loc[index, 'having_sub_domain'] != is_having_sub_domain(df_phish.loc[index, 'website_url']):
#         print(f"Subdomain mismatch at index {index}.")
#         print(f"{df_phish.loc[index,'website_url']}, {df_phish.loc[index, 'having_sub_domain']}, {is_having_sub_domain(df_phish.loc[index, 'website_url'])}")

df_phish['website_url'].apply(is_dns_record)
# Out:
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D0162410>
# A records: <dns.resolver.Answer object at 0x000001D2D04FDE10>
# No A records
# No AAAA records
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D04FFF10>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE210>
# A records: <dns.resolver.Answer object at 0x000001D2D048EF10>
# A records: <dns.resolver.Answer object at 0x000001D2D04FCE10>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE750>
# A records: <dns.resolver.Answer object at 0x000001D2D0529990>
# A records: <dns.resolver.Answer object at 0x000001D2D052B9D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0301150>
# A records: <dns.resolver.Answer object at 0x000001D2D048EF50>
# A records: <dns.resolver.Answer object at 0x000001D2D052B190>
# A records: <dns.resolver.Answer object at 0x000001D2D0529BD0>
# A records: <dns.resolver.Answer object at 0x000001D2D052B410>
# A records: <dns.resolver.Answer object at 0x000001D2D04C9210>
# A records: <dns.resolver.Answer object at 0x000001D2D0529990>
# A records: <dns.resolver.Answer object at 0x000001D2D052BC10>
# A records: <dns.resolver.Answer object at 0x000001D2D048EF10>
# A records: <dns.resolver.Answer object at 0x000001D2D0242610>
# A records: <dns.resolver.Answer object at 0x000001D2D0301150>
# A records: <dns.resolver.Answer object at 0x000001D2D0453C10>
# A records: <dns.resolver.Answer object at 0x000001D2D052B210>
# A records: <dns.resolver.Answer object at 0x000001D2D04FF550>
# A records: <dns.resolver.Answer object at 0x000001D2D052A190>
# A records: <dns.resolver.Answer object at 0x000001D2D0528710>
# A records: <dns.resolver.Answer object at 0x000001D2D0529D90>
# A records: <dns.resolver.Answer object at 0x000001D2D0529B10>
# No A records
# No AAAA records
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D052BD10>
# NXDOMAIN
# No A records
# No AAAA records
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D04FE750>
# A records: <dns.resolver.Answer object at 0x000001D2D053B190>
# A records: <dns.resolver.Answer object at 0x000001D2D053B350>
# A records: <dns.resolver.Answer object at 0x000001D2D0538FD0>
# A records: <dns.resolver.Answer object at 0x000001D2D0538150>
# A records: <dns.resolver.Answer object at 0x000001D2D0539810>
# A records: <dns.resolver.Answer object at 0x000001D2D0539ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D053BF10>
# A records: <dns.resolver.Answer object at 0x000001D2D053BC90>
# A records: <dns.resolver.Answer object at 0x000001D2D053AA90>
# A records: <dns.resolver.Answer object at 0x000001D2D0539690>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D053BC90>
# A records: <dns.resolver.Answer object at 0x000001D2D053B710>
# A records: <dns.resolver.Answer object at 0x000001D2D053AE50>
# A records: <dns.resolver.Answer object at 0x000001D2D0539ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D052B5D0>
# A records: <dns.resolver.Answer object at 0x000001D2D053B750>
# A records: <dns.resolver.Answer object at 0x000001D2D053A510>
# A records: <dns.resolver.Answer object at 0x000001D2D0539ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D0539DD0>
# A records: <dns.resolver.Answer object at 0x000001D2D053A990>
# A records: <dns.resolver.Answer object at 0x000001D2D053B890>
# A records: <dns.resolver.Answer object at 0x000001D2D0539290>
# A records: <dns.resolver.Answer object at 0x000001D2D053A610>
# A records: <dns.resolver.Answer object at 0x000001D2D053A990>
# A records: <dns.resolver.Answer object at 0x000001D2D053B890>
# A records: <dns.resolver.Answer object at 0x000001D2D052AD50>
# A records: <dns.resolver.Answer object at 0x000001D2D0529010>
# A records: <dns.resolver.Answer object at 0x000001D2D053B890>
# A records: <dns.resolver.Answer object at 0x000001D2D048EE90>
# A records: <dns.resolver.Answer object at 0x000001D2D053A9D0>
# No A records
# No AAAA records
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2CD8B2C10>
# A records: <dns.resolver.Answer object at 0x000001D2D053BA90>
# A records: <dns.resolver.Answer object at 0x000001D2D053A3D0>
# A records: <dns.resolver.Answer object at 0x000001D2D053BC10>
# A records: <dns.resolver.Answer object at 0x000001D2D0538FD0>
# A records: <dns.resolver.Answer object at 0x000001D2D053A7D0>
# A records: <dns.resolver.Answer object at 0x000001D2D053A610>
# A records: <dns.resolver.Answer object at 0x000001D2D0539DD0>
# A records: <dns.resolver.Answer object at 0x000001D2D0538790>
# A records: <dns.resolver.Answer object at 0x000001D2D05380D0>
# A records: <dns.resolver.Answer object at 0x000001D2D053B710>
# A records: <dns.resolver.Answer object at 0x000001D2D053A210>
# A records: <dns.resolver.Answer object at 0x000001D2D053B310>
# A records: <dns.resolver.Answer object at 0x000001D2D0539910>
# A records: <dns.resolver.Answer object at 0x000001D2D053AA90>
# A records: <dns.resolver.Answer object at 0x000001D2D0538850>
# A records: <dns.resolver.Answer object at 0x000001D2D053A910>
# A records: <dns.resolver.Answer object at 0x000001D2D053A3D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0539810>
# A records: <dns.resolver.Answer object at 0x000001D2D0539490>
# A records: <dns.resolver.Answer object at 0x000001D2D0538B50>
# A records: <dns.resolver.Answer object at 0x000001D2D053A950>
# A records: <dns.resolver.Answer object at 0x000001D2D0538B50>
# A records: <dns.resolver.Answer object at 0x000001D2D0539950>
# A records: <dns.resolver.Answer object at 0x000001D2D053A910>
# A records: <dns.resolver.Answer object at 0x000001D2D048EF10>
# A records: <dns.resolver.Answer object at 0x000001D2D03FE010>
# No A records
# No AAAA records
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2B4F59810>
# A records: <dns.resolver.Answer object at 0x000001D2D053AB10>
# A records: <dns.resolver.Answer object at 0x000001D2D052AB10>
# A records: <dns.resolver.Answer object at 0x000001D2D0528C10>
# A records: <dns.resolver.Answer object at 0x000001D2D053ADD0>
# A records: <dns.resolver.Answer object at 0x000001D2D052A5D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0529D90>
# A records: <dns.resolver.Answer object at 0x000001D2D052A410>
# A records: <dns.resolver.Answer object at 0x000001D2D052B210>
# A records: <dns.resolver.Answer object at 0x000001D2D052B190>
# A records: <dns.resolver.Answer object at 0x000001D2D0529D90>
# A records: <dns.resolver.Answer object at 0x000001D2D0529F90>
# A records: <dns.resolver.Answer object at 0x000001D2D0529E90>
# A records: <dns.resolver.Answer object at 0x000001D2D052AAD0>
# A records: <dns.resolver.Answer object at 0x000001D2D0529D90>
# A records: <dns.resolver.Answer object at 0x000001D2D052A350>
# A records: <dns.resolver.Answer object at 0x000001D2D052B410>
# A records: <dns.resolver.Answer object at 0x000001D2D0529FD0>
# A records: <dns.resolver.Answer object at 0x000001D2D0529D90>
# A records: <dns.resolver.Answer object at 0x000001D2D052A0D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0529C50>
# A records: <dns.resolver.Answer object at 0x000001D2CDD60F90>
# A records: <dns.resolver.Answer object at 0x000001D2D0529250>
# A records: <dns.resolver.Answer object at 0x000001D2D052B850>
# No A records
# No AAAA records
# NXDOMAIN
# A records: <dns.resolver.Answer object at 0x000001D2D0529C50>
# A records: <dns.resolver.Answer object at 0x000001D2D0539B10>
# A records: <dns.resolver.Answer object at 0x000001D2D053A610>
# A records: <dns.resolver.Answer object at 0x000001D2CDD5FC90>
# A records: <dns.resolver.Answer object at 0x000001D2D04FEB10>
# A records: <dns.resolver.Answer object at 0x000001D2D04FD510>
# A records: <dns.resolver.Answer object at 0x000001D2D04FEA90>
# A records: <dns.resolver.Answer object at 0x000001D2D053A610>
# A records: <dns.resolver.Answer object at 0x000001D2D04FEA90>
# A records: <dns.resolver.Answer object at 0x000001D2D02ADC90>
# A records: <dns.resolver.Answer object at 0x000001D2D0160A90>
# A records: <dns.resolver.Answer object at 0x000001D2D0162410>
# A records: <dns.resolver.Answer object at 0x000001D2D04C83D0>
# A records: <dns.resolver.Answer object at 0x000001D2D05380D0>
# A records: <dns.resolver.Answer object at 0x000001D2D053B310>
# A records: <dns.resolver.Answer object at 0x000001D2D05380D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FD510>
# A records: <dns.resolver.Answer object at 0x000001D2D04C9810>
# A records: <dns.resolver.Answer object at 0x000001D2D04CAA90>
# A records: <dns.resolver.Answer object at 0x000001D2D05289D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FEA90>
# A records: <dns.resolver.Answer object at 0x000001D2D03FDD50>
# A records: <dns.resolver.Answer object at 0x000001D2D04C9810>
# A records: <dns.resolver.Answer object at 0x000001D2D03FDD50>
# A records: <dns.resolver.Answer object at 0x000001D2D0454050>
# A records: <dns.resolver.Answer object at 0x000001D2D0160A90>
# A records: <dns.resolver.Answer object at 0x000001D2D045D0D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE210>
# A records: <dns.resolver.Answer object at 0x000001D2D045D0D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FD9D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0160A90>
# A records: <dns.resolver.Answer object at 0x000001D2D0301150>
# A records: <dns.resolver.Answer object at 0x000001D2D05289D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE210>
# A records: <dns.resolver.Answer object at 0x000001D2D02ADC90>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2CDD5FE90>
# A records: <dns.resolver.Answer object at 0x000001D2D04F0A10>
# NXDOMAIN
# NXDOMAIN
# NXDOMAIN
# A records: <dns.resolver.Answer object at 0x000001D2D04F35D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04F0D90>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3D90>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1410>
# A records: <dns.resolver.Answer object at 0x000001D2D04F2E90>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1650>
# A records: <dns.resolver.Answer object at 0x000001D2D04F0C50>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1150>
# A records: <dns.resolver.Answer object at 0x000001D2D04F0C50>
# A records: <dns.resolver.Answer object at 0x000001D2D02402D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04CAA90>
# A records: <dns.resolver.Answer object at 0x000001D2D04CAA90>
# A records: <dns.resolver.Answer object at 0x000001D2D016EC90>
# A records: <dns.resolver.Answer object at 0x000001D2D04CAA90>
# A records: <dns.resolver.Answer object at 0x000001D2D0457D50>
# A records: <dns.resolver.Answer object at 0x000001D2D04FD7D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE210>
# A records: <dns.resolver.Answer object at 0x000001D2D04FFFD0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FF490>
# A records: <dns.resolver.Answer object at 0x000001D2D04FD650>
# A records: <dns.resolver.Answer object at 0x000001D2D0162410>
# A records: <dns.resolver.Answer object at 0x000001D2D04FD650>
# A records: <dns.resolver.Answer object at 0x000001D2D04FEE50>
# A records: <dns.resolver.Answer object at 0x000001D2D03FE010>
# A records: <dns.resolver.Answer object at 0x000001D2D048EF50>
# A records: <dns.resolver.Answer object at 0x000001D2CBBE2A90>
# A records: <dns.resolver.Answer object at 0x000001D2D02ADC90>
# A records: <dns.resolver.Answer object at 0x000001D2B4F59810>
# A records: <dns.resolver.Answer object at 0x000001D2CBE04E50>
# A records: <dns.resolver.Answer object at 0x000001D2D02402D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04F0450>
# A records: <dns.resolver.Answer object at 0x000001D2D0528E50>
# A records: <dns.resolver.Answer object at 0x000001D2D048EF50>
# A records: <dns.resolver.Answer object at 0x000001D2D01276D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0453150>
# A records: <dns.resolver.Answer object at 0x000001D2D048EF50>
# A records: <dns.resolver.Answer object at 0x000001D2D0454050>
# A records: <dns.resolver.Answer object at 0x000001D2D048EF50>
# A records: <dns.resolver.Answer object at 0x000001D2D0528750>
# A records: <dns.resolver.Answer object at 0x000001D2D052BB90>
# A records: <dns.resolver.Answer object at 0x000001D2D052A590>
# A records: <dns.resolver.Answer object at 0x000001D2D052BA90>
# A records: <dns.resolver.Answer object at 0x000001D2D052AE10>
# A records: <dns.resolver.Answer object at 0x000001D2D052BB90>
# A records: <dns.resolver.Answer object at 0x000001D2D0528C10>
# A records: <dns.resolver.Answer object at 0x000001D2D052AE50>
# A records: <dns.resolver.Answer object at 0x000001D2D0528350>
# No A records
# AAAA records: <dns.resolver.Answer object at 0x000001D2CD89B750>
# A records: <dns.resolver.Answer object at 0x000001D2D03FDD50>
# A records: <dns.resolver.Answer object at 0x000001D2D03FDD50>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1410>
# A records: <dns.resolver.Answer object at 0x000001D2D0183310>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1250>
# A records: <dns.resolver.Answer object at 0x000001D2D0539B10>
# A records: <dns.resolver.Answer object at 0x000001D2D053B690>
# A records: <dns.resolver.Answer object at 0x000001D2D053A950>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC3D0>
# A records: <dns.resolver.Answer object at 0x000001D2D052BD10>
# A records: <dns.resolver.Answer object at 0x000001D2D048EF50>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D052AA10>
# A records: <dns.resolver.Answer object at 0x000001D2D0538C90>
# A records: <dns.resolver.Answer object at 0x000001D2CFB58ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D053AE50>
# A records: <dns.resolver.Answer object at 0x000001D2D053B350>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D04C86D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0457D50>
# A records: <dns.resolver.Answer object at 0x000001D2D0538B10>
# A records: <dns.resolver.Answer object at 0x000001D2D0539490>
# A records: <dns.resolver.Answer object at 0x000001D2D0538750>
# A records: <dns.resolver.Answer object at 0x000001D2D053B750>
# A records: <dns.resolver.Answer object at 0x000001D2D053A9D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0453150>
# A records: <dns.resolver.Answer object at 0x000001D2D053BB50>
# A records: <dns.resolver.Answer object at 0x000001D2D053B750>
# A records: <dns.resolver.Answer object at 0x000001D2D053BB50>
# A records: <dns.resolver.Answer object at 0x000001D2D053B750>
# A records: <dns.resolver.Answer object at 0x000001D2CDD60F90>
# A records: <dns.resolver.Answer object at 0x000001D2D0454050>
# A records: <dns.resolver.Answer object at 0x000001D2B4F5B9D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0182ED0>
# A records: <dns.resolver.Answer object at 0x000001D2CDD60F90>
# A records: <dns.resolver.Answer object at 0x000001D2D03FDD50>
# A records: <dns.resolver.Answer object at 0x000001D2D0253150>
# A records: <dns.resolver.Answer object at 0x000001D2D052AA10>
# A records: <dns.resolver.Answer object at 0x000001D2D0454050>
# A records: <dns.resolver.Answer object at 0x000001D2D03ECF50>
# A records: <dns.resolver.Answer object at 0x000001D2D04F0C50>
# A records: <dns.resolver.Answer object at 0x000001D2D0240990>
# A records: <dns.resolver.Answer object at 0x000001D2D03FF2D0>
# A records: <dns.resolver.Answer object at 0x000001D2B4F882D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0539D50>
# A records: <dns.resolver.Answer object at 0x000001D2D053BF10>
# A records: <dns.resolver.Answer object at 0x000001D2D053BC10>
# A records: <dns.resolver.Answer object at 0x000001D2D053BB10>
# A records: <dns.resolver.Answer object at 0x000001D2D0539DD0>
# A records: <dns.resolver.Answer object at 0x000001D2D053BB10>
# A records: <dns.resolver.Answer object at 0x000001D2D0539910>
# A records: <dns.resolver.Answer object at 0x000001D2D053B710>
# A records: <dns.resolver.Answer object at 0x000001D2D0539B10>
# A records: <dns.resolver.Answer object at 0x000001D2D0538050>
# A records: <dns.resolver.Answer object at 0x000001D2D0538C90>
# A records: <dns.resolver.Answer object at 0x000001D2D053B710>
# A records: <dns.resolver.Answer object at 0x000001D2D053AF90>
# A records: <dns.resolver.Answer object at 0x000001D2D0538310>
# A records: <dns.resolver.Answer object at 0x000001D2D053AC50>
# A records: <dns.resolver.Answer object at 0x000001D2D053A850>
# A records: <dns.resolver.Answer object at 0x000001D2D053B2D0>
# A records: <dns.resolver.Answer object at 0x000001D2D053ADD0>
# A records: <dns.resolver.Answer object at 0x000001D2B4F59810>
# A records: <dns.resolver.Answer object at 0x000001D2D0538A50>
# A records: <dns.resolver.Answer object at 0x000001D2CD89B750>
# A records: <dns.resolver.Answer object at 0x000001D2D053AF90>
# A records: <dns.resolver.Answer object at 0x000001D2D053AB50>
# A records: <dns.resolver.Answer object at 0x000001D2D0528750>
# A records: <dns.resolver.Answer object at 0x000001D2D0457D50>
# A records: <dns.resolver.Answer object at 0x000001D2D052AA10>
# A records: <dns.resolver.Answer object at 0x000001D2D052A950>
# A records: <dns.resolver.Answer object at 0x000001D2D0528750>
# A records: <dns.resolver.Answer object at 0x000001D2D052BA90>
# A records: <dns.resolver.Answer object at 0x000001D2D052B110>
# A records: <dns.resolver.Answer object at 0x000001D2D052A950>
# A records: <dns.resolver.Answer object at 0x000001D2D052AA10>
# A records: <dns.resolver.Answer object at 0x000001D2D052A4D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0529E90>
# A records: <dns.resolver.Answer object at 0x000001D2D052B210>
# A records: <dns.resolver.Answer object at 0x000001D2D052ADD0>
# A records: <dns.resolver.Answer object at 0x000001D2D048EF50>
# A records: <dns.resolver.Answer object at 0x000001D2D02F8850>
# A records: <dns.resolver.Answer object at 0x000001D2CD89B5D0>
# A records: <dns.resolver.Answer object at 0x000001D2CF8AF010>
# A records: <dns.resolver.Answer object at 0x000001D2D0453150>
# A records: <dns.resolver.Answer object at 0x000001D2D05294D0>
# A records: <dns.resolver.Answer object at 0x000001D2D05294D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0183310>
# A records: <dns.resolver.Answer object at 0x000001D2D048C3D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0538310>
# A records: <dns.resolver.Answer object at 0x000001D2D0453F90>
# A records: <dns.resolver.Answer object at 0x000001D2D053BD90>
# A records: <dns.resolver.Answer object at 0x000001D2D0453F90>
# A records: <dns.resolver.Answer object at 0x000001D2CBBE2A90>
# A records: <dns.resolver.Answer object at 0x000001D2D053ADD0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FEB10>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC150>
# A records: <dns.resolver.Answer object at 0x000001D2D04FEB10>
# A records: <dns.resolver.Answer object at 0x000001D2D03FF290>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC410>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC410>
# A records: <dns.resolver.Answer object at 0x000001D2D05380D0>
# A records: <dns.resolver.Answer object at 0x000001D2CD89B750>
# A records: <dns.resolver.Answer object at 0x000001D2D0457D50>
# A records: <dns.resolver.Answer object at 0x000001D2D05380D0>
# A records: <dns.resolver.Answer object at 0x000001D2CDD5FE90>
# A records: <dns.resolver.Answer object at 0x000001D2D048C3D0>
# A records: <dns.resolver.Answer object at 0x000001D2D048E210>
# A records: <dns.resolver.Answer object at 0x000001D2D03EFC10>
# A records: <dns.resolver.Answer object at 0x000001D2D03EF750>
# A records: <dns.resolver.Answer object at 0x000001D2D0240990>
# A records: <dns.resolver.Answer object at 0x000001D2CDD5FE90>
# A records: <dns.resolver.Answer object at 0x000001D2CBBE2A90>
# A records: <dns.resolver.Answer object at 0x000001D2D052A950>
# A records: <dns.resolver.Answer object at 0x000001D2D0538A50>
# A records: <dns.resolver.Answer object at 0x000001D2D04CBE10>
# A records: <dns.resolver.Answer object at 0x000001D2D0240990>
# A records: <dns.resolver.Answer object at 0x000001D2D048C3D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0183310>
# A records: <dns.resolver.Answer object at 0x000001D2D04FEB10>
# A records: <dns.resolver.Answer object at 0x000001D2D04C9CD0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FEB10>
# A records: <dns.resolver.Answer object at 0x000001D2D03FDD50>
# A records: <dns.resolver.Answer object at 0x000001D2D04C9CD0>
# A records: <dns.resolver.Answer object at 0x000001D2CD8A21D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0539DD0>
# A records: <dns.resolver.Answer object at 0x000001D2CD89B5D0>
# A records: <dns.resolver.Answer object at 0x000001D2CFB58ED0>
# A records: <dns.resolver.Answer object at 0x000001D2B4F59810>
# A records: <dns.resolver.Answer object at 0x000001D2D04CBE10>
# A records: <dns.resolver.Answer object at 0x000001D2D0453F90>
# A records: <dns.resolver.Answer object at 0x000001D2D03EF750>
# A records: <dns.resolver.Answer object at 0x000001D2B4F882D0>
# A records: <dns.resolver.Answer object at 0x000001D2CDD5FE90>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1210>
# A records: <dns.resolver.Answer object at 0x000001D2CD8A21D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0183310>
# A records: <dns.resolver.Answer object at 0x000001D2D0454050>
# A records: <dns.resolver.Answer object at 0x000001D2D03FDD50>
# A records: <dns.resolver.Answer object at 0x000001D2D0373750>
# A records: <dns.resolver.Answer object at 0x000001D2D0242610>
# A records: <dns.resolver.Answer object at 0x000001D2D03EF750>
# A records: <dns.resolver.Answer object at 0x000001D2D03ED950>
# A records: <dns.resolver.Answer object at 0x000001D2D03EF190>
# A records: <dns.resolver.Answer object at 0x000001D2D03EC150>
# A records: <dns.resolver.Answer object at 0x000001D2D03EC4D0>
# A records: <dns.resolver.Answer object at 0x000001D2D03ECF50>
# A records: <dns.resolver.Answer object at 0x000001D2D03EC150>
# A records: <dns.resolver.Answer object at 0x000001D2D03EE690>
# A records: <dns.resolver.Answer object at 0x000001D2CD89B5D0>
# A records: <dns.resolver.Answer object at 0x000001D2D03EC150>
# A records: <dns.resolver.Answer object at 0x000001D2D03ED210>
# A records: <dns.resolver.Answer object at 0x000001D2D03ECE50>
# A records: <dns.resolver.Answer object at 0x000001D2D03ED210>
# A records: <dns.resolver.Answer object at 0x000001D2D048E210>
# A records: <dns.resolver.Answer object at 0x000001D2CFB58ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D04CBE10>
# A records: <dns.resolver.Answer object at 0x000001D2D04CA050>
# A records: <dns.resolver.Answer object at 0x000001D2CF8AF010>
# A records: <dns.resolver.Answer object at 0x000001D2D03ECE50>
# A records: <dns.resolver.Answer object at 0x000001D2D021B150>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1C90>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3290>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1DD0>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3490>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1110>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3D10>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3290>
# A records: <dns.resolver.Answer object at 0x000001D2D0457D50>
# A records: <dns.resolver.Answer object at 0x000001D2D04F03D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3490>
# A records: <dns.resolver.Answer object at 0x000001D2D0457D50>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D04F37D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FFFD0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC410>
# A records: <dns.resolver.Answer object at 0x000001D2D04FFFD0>
# A records: <dns.resolver.Answer object at 0x000001D2D0373750>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE550>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC990>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE550>
# A records: <dns.resolver.Answer object at 0x000001D2D04F0A10>
# A records: <dns.resolver.Answer object at 0x000001D2D048E210>
# A records: <dns.resolver.Answer object at 0x000001D2CDD60F90>
# A records: <dns.resolver.Answer object at 0x000001D2D0240990>
# A records: <dns.resolver.Answer object at 0x000001D2D0528290>
# A records: <dns.resolver.Answer object at 0x000001D2D01276D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3290>
# A records: <dns.resolver.Answer object at 0x000001D2D0528350>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D0528110>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D052BB90>
# A records: <dns.resolver.Answer object at 0x000001D2D0529610>
# A records: <dns.resolver.Answer object at 0x000001D2D052A390>
# A records: <dns.resolver.Answer object at 0x000001D2D04C9CD0>
# A records: <dns.resolver.Answer object at 0x000001D2D04CBE10>
# A records: <dns.resolver.Answer object at 0x000001D2D052A410>
# A records: <dns.resolver.Answer object at 0x000001D2D05282D0>
# A records: <dns.resolver.Answer object at 0x000001D2D052BE90>
# A records: <dns.resolver.Answer object at 0x000001D2D053B5D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0538310>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D048E210>
# A records: <dns.resolver.Answer object at 0x000001D2D0373750>
# A records: <dns.resolver.Answer object at 0x000001D2D04C8B10>
# A records: <dns.resolver.Answer object at 0x000001D2D053AA90>
# A records: <dns.resolver.Answer object at 0x000001D2D0373750>
# A records: <dns.resolver.Answer object at 0x000001D2D053BC10>
# A records: <dns.resolver.Answer object at 0x000001D2D0539D50>
# A records: <dns.resolver.Answer object at 0x000001D2D0539950>
# A records: <dns.resolver.Answer object at 0x000001D2D053B190>
# A records: <dns.resolver.Answer object at 0x000001D2CDD60F90>
# A records: <dns.resolver.Answer object at 0x000001D2D0452ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D0538C90>
# A records: <dns.resolver.Answer object at 0x000001D2D0539210>
# A records: <dns.resolver.Answer object at 0x000001D2D053B390>
# A records: <dns.resolver.Answer object at 0x000001D2D05299D0>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D0538E10>
# A records: <dns.resolver.Answer object at 0x000001D2D04F03D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0240990>
# A records: <dns.resolver.Answer object at 0x000001D2CD89B5D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0373850>
# A records: <dns.resolver.Answer object at 0x000001D2D03ED210>
# A records: <dns.resolver.Answer object at 0x000001D2D0539910>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1C90>
# A records: <dns.resolver.Answer object at 0x000001D2D050ADD0>
# A records: <dns.resolver.Answer object at 0x000001D2D045D0D0>
# A records: <dns.resolver.Answer object at 0x000001D2D053A450>
# A records: <dns.resolver.Answer object at 0x000001D2D053B390>
# A records: <dns.resolver.Answer object at 0x000001D2D053A190>
# A records: <dns.resolver.Answer object at 0x000001D2D053AF90>
# A records: <dns.resolver.Answer object at 0x000001D2D053A190>
# A records: <dns.resolver.Answer object at 0x000001D2D0539A50>
# A records: <dns.resolver.Answer object at 0x000001D2D053B4D0>
# A records: <dns.resolver.Answer object at 0x000001D2D053B5D0>
# A records: <dns.resolver.Answer object at 0x000001D2D053A850>
# A records: <dns.resolver.Answer object at 0x000001D2D053ADD0>
# No A records
# No AAAA records
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D053ADD0>
# A records: <dns.resolver.Answer object at 0x000001D2D053AF90>
# A records: <dns.resolver.Answer object at 0x000001D2D053BCD0>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D0451E10>
# A records: <dns.resolver.Answer object at 0x000001D2D0529890>
# A records: <dns.resolver.Answer object at 0x000001D2D05288D0>
# No A records
# No AAAA records
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D052AAD0>
# A records: <dns.resolver.Answer object at 0x000001D2D0528C10>
# A records: <dns.resolver.Answer object at 0x000001D2D0528290>
# A records: <dns.resolver.Answer object at 0x000001D2D0528350>
# A records: <dns.resolver.Answer object at 0x000001D2D0529250>
# A records: <dns.resolver.Answer object at 0x000001D2D05295D0>
# A records: <dns.resolver.Answer object at 0x000001D2B4F5B9D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0457D50>
# A records: <dns.resolver.Answer object at 0x000001D2D0240990>
# A records: <dns.resolver.Answer object at 0x000001D2D0528B50>
# A records: <dns.resolver.Answer object at 0x000001D2CD89B5D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0528910>
# A records: <dns.resolver.Answer object at 0x000001D2D053B310>
# A records: <dns.resolver.Answer object at 0x000001D2D0538250>
# A records: <dns.resolver.Answer object at 0x000001D2D0453C10>
# No A records
# No AAAA records
# No A records
# No AAAA records
# No A records
# No AAAA records
# No A records
# No AAAA records
# No A records
# No AAAA records
# No A records
# No AAAA records
# No A records
# No AAAA records
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D04FC990>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1290>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D0243110>
# A records: <dns.resolver.Answer object at 0x000001D2D04F35D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1250>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1810>
# A records: <dns.resolver.Answer object at 0x000001D2D0240990>
# A records: <dns.resolver.Answer object at 0x000001D2D04F09D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04F0F10>
# A records: <dns.resolver.Answer object at 0x000001D2D052BD90>
# A records: <dns.resolver.Answer object at 0x000001D2D021B150>
# A records: <dns.resolver.Answer object at 0x000001D2D048E210>
# A records: <dns.resolver.Answer object at 0x000001D2D04FF550>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3A90>
# A records: <dns.resolver.Answer object at 0x000001D2D053B4D0>
# A records: <dns.resolver.Answer object at 0x000001D2D053AF90>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE090>
# A records: <dns.resolver.Answer object at 0x000001D2D053AF90>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2B4F882D0>
# NXDOMAIN
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D04FC990>
# NXDOMAIN
# NXDOMAIN
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D02F9D90>
# A records: <dns.resolver.Answer object at 0x000001D2D03EE390>
# NXDOMAIN
# A records: <dns.resolver.Answer object at 0x000001D2D050AD90>
# A records: <dns.resolver.Answer object at 0x000001D2D0508A90>
# A records: <dns.resolver.Answer object at 0x000001D2D04F0F50>
# A records: <dns.resolver.Answer object at 0x000001D2B4F5B9D0>
# A records: <dns.resolver.Answer object at 0x000001D2CB762ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D0457D50>
# A records: <dns.resolver.Answer object at 0x000001D2D0453150>
# A records: <dns.resolver.Answer object at 0x000001D2D03ECBD0>
# A records: <dns.resolver.Answer object at 0x000001D2D03ED110>
# A records: <dns.resolver.Answer object at 0x000001D2D03ECF50>
# A records: <dns.resolver.Answer object at 0x000001D2D03EDFD0>
# A records: <dns.resolver.Answer object at 0x000001D2D03ED110>
# A records: <dns.resolver.Answer object at 0x000001D2D03EFED0>
# A records: <dns.resolver.Answer object at 0x000001D2D03EF750>
# A records: <dns.resolver.Answer object at 0x000001D2D03EC1D0>
# A records: <dns.resolver.Answer object at 0x000001D2D03EF750>
# A records: <dns.resolver.Answer object at 0x000001D2D0457D50>
# A records: <dns.resolver.Answer object at 0x000001D2D03EC110>
# A records: <dns.resolver.Answer object at 0x000001D2D03EC1D0>
# A records: <dns.resolver.Answer object at 0x000001D2D03EFED0>
# A records: <dns.resolver.Answer object at 0x000001D2CD8C0DD0>
# A records: <dns.resolver.Answer object at 0x000001D2D03EC1D0>
# A records: <dns.resolver.Answer object at 0x000001D2D03EC110>
# A records: <dns.resolver.Answer object at 0x000001D2D0453F90>
# A records: <dns.resolver.Answer object at 0x000001D2D04C86D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04C8A10>
# A records: <dns.resolver.Answer object at 0x000001D2D0183310>
# A records: <dns.resolver.Answer object at 0x000001D2D04C8A10>
# A records: <dns.resolver.Answer object at 0x000001D2D048F2D0>
# A records: <dns.resolver.Answer object at 0x000001D2CD8A21D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04C8A10>
# A records: <dns.resolver.Answer object at 0x000001D2D03EF750>
# A records: <dns.resolver.Answer object at 0x000001D2D0301150>
# A records: <dns.resolver.Answer object at 0x000001D2D0183110>
# A records: <dns.resolver.Answer object at 0x000001D2D0163A10>
# A records: <dns.resolver.Answer object at 0x000001D2D048F2D0>
# A records: <dns.resolver.Answer object at 0x000001D2CB762ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3890>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1790>
# A records: <dns.resolver.Answer object at 0x000001D2D04F2790>
# A records: <dns.resolver.Answer object at 0x000001D2CBAA1E50>
# A records: <dns.resolver.Answer object at 0x000001D2D04F39D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3890>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3C50>
# A records: <dns.resolver.Answer object at 0x000001D2D04F2190>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3B50>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1510>
# A records: <dns.resolver.Answer object at 0x000001D2B4F59810>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3C50>
# A records: <dns.resolver.Answer object at 0x000001D2D03EE210>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE750>
# A records: <dns.resolver.Answer object at 0x000001D2B4F59810>
# A records: <dns.resolver.Answer object at 0x000001D2D03EE210>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC990>
# A records: <dns.resolver.Answer object at 0x000001D2D04FEE90>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC9D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FF490>
# A records: <dns.resolver.Answer object at 0x000001D2D04FD5D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FF490>
# A records: <dns.resolver.Answer object at 0x000001D2D04FD7D0>
# A records: <dns.resolver.Answer object at 0x000001D2CB762ED0>
# A records: <dns.resolver.Answer object at 0x000001D2CB0C9290>
# A records: <dns.resolver.Answer object at 0x000001D2D04FFF90>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE590>
# A records: <dns.resolver.Answer object at 0x000001D2D04FDA10>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC450>
# A records: <dns.resolver.Answer object at 0x000001D2CDD5FE90>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D04FE590>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D04FCE50>
# A records: <dns.resolver.Answer object at 0x000001D2D0457D50>
# A records: <dns.resolver.Answer object at 0x000001D2D045D0D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0538850>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE590>
# A records: <dns.resolver.Answer object at 0x000001D2D0538050>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3C50>
# A records: <dns.resolver.Answer object at 0x000001D2D053BB10>
# A records: <dns.resolver.Answer object at 0x000001D2D053BA10>
# A records: <dns.resolver.Answer object at 0x000001D2D0538510>
# A records: <dns.resolver.Answer object at 0x000001D2D053BA10>
# A records: <dns.resolver.Answer object at 0x000001D2D04FEE90>
# A records: <dns.resolver.Answer object at 0x000001D2D053B650>
# A records: <dns.resolver.Answer object at 0x000001D2D0182ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D0538210>
# A records: <dns.resolver.Answer object at 0x000001D2D0539B90>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE590>
# A records: <dns.resolver.Answer object at 0x000001D2D053BB10>
# A records: <dns.resolver.Answer object at 0x000001D2D0538510>
# A records: <dns.resolver.Answer object at 0x000001D2D04FDA10>
# A records: <dns.resolver.Answer object at 0x000001D2D0451510>
# A records: <dns.resolver.Answer object at 0x000001D2D0529D10>
# A records: <dns.resolver.Answer object at 0x000001D2CBAA1E50>
# A records: <dns.resolver.Answer object at 0x000001D2D05295D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0373850>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC450>
# A records: <dns.resolver.Answer object at 0x000001D2D0456D90>
# A records: <dns.resolver.Answer object at 0x000001D2D053BB90>
# A records: <dns.resolver.Answer object at 0x000001D2D0539E10>
# A records: <dns.resolver.Answer object at 0x000001D2D0538510>
# A records: <dns.resolver.Answer object at 0x000001D2D053A910>
# A records: <dns.resolver.Answer object at 0x000001D2D053A4D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0538150>
# A records: <dns.resolver.Answer object at 0x000001D2D0539810>
# A records: <dns.resolver.Answer object at 0x000001D2D053A4D0>
# A records: <dns.resolver.Answer object at 0x000001D2D053B710>
# A records: <dns.resolver.Answer object at 0x000001D2D0539710>
# A records: <dns.resolver.Answer object at 0x000001D2D0538150>
# A records: <dns.resolver.Answer object at 0x000001D2D0539810>
# A records: <dns.resolver.Answer object at 0x000001D2D053AA90>
# A records: <dns.resolver.Answer object at 0x000001D2D053B710>
# A records: <dns.resolver.Answer object at 0x000001D2D0539810>
# A records: <dns.resolver.Answer object at 0x000001D2D0539E90>
# A records: <dns.resolver.Answer object at 0x000001D2D053AA90>
# A records: <dns.resolver.Answer object at 0x000001D2D053B510>
# A records: <dns.resolver.Answer object at 0x000001D2D053A490>
# A records: <dns.resolver.Answer object at 0x000001D2D0539650>
# A records: <dns.resolver.Answer object at 0x000001D2D02F9D90>
# A records: <dns.resolver.Answer object at 0x000001D2CD8A21D0>
# A records: <dns.resolver.Answer object at 0x000001D2D02F9D90>
# A records: <dns.resolver.Answer object at 0x000001D2D0253150>
# A records: <dns.resolver.Answer object at 0x000001D2D02F9D90>
# A records: <dns.resolver.Answer object at 0x000001D2D03017D0>
# A records: <dns.resolver.Answer object at 0x000001D2D02F9D90>
# A records: <dns.resolver.Answer object at 0x000001D2D0346F90>
# A records: <dns.resolver.Answer object at 0x000001D2B4F812D0>
# A records: <dns.resolver.Answer object at 0x000001D2D053B510>
# A records: <dns.resolver.Answer object at 0x000001D2D053BF90>
# A records: <dns.resolver.Answer object at 0x000001D2B4F812D0>
# A records: <dns.resolver.Answer object at 0x000001D2CDD5FE90>
# A records: <dns.resolver.Answer object at 0x000001D2B4F59810>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE510>
# A records: <dns.resolver.Answer object at 0x000001D2D04FF350>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC750>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1790>
# A records: <dns.resolver.Answer object at 0x000001D2D04F39D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3190>
# A records: <dns.resolver.Answer object at 0x000001D2CB762ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D02F9D90>
# A records: <dns.resolver.Answer object at 0x000001D2D0182ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D053A510>
# A records: <dns.resolver.Answer object at 0x000001D2D0163A10>
# A records: <dns.resolver.Answer object at 0x000001D2CD8A21D0>
# A records: <dns.resolver.Answer object at 0x000001D2D053B710>
# A records: <dns.resolver.Answer object at 0x000001D2D03017D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0346F90>
# A records: <dns.resolver.Answer object at 0x000001D2D04FF350>
# A records: <dns.resolver.Answer object at 0x000001D2D045D0D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04F23D0>
# A records: <dns.resolver.Answer object at 0x000001D2CBE04E50>
# A records: <dns.resolver.Answer object at 0x000001D2D0253150>
# A records: <dns.resolver.Answer object at 0x000001D2D053A490>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3A90>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3810>
# A records: <dns.resolver.Answer object at 0x000001D2D04F23D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC750>
# A records: <dns.resolver.Answer object at 0x000001D2CBAA1E50>
# A records: <dns.resolver.Answer object at 0x000001D2D04F23D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04CABD0>
# A records: <dns.resolver.Answer object at 0x000001D2CDD5D790>
# A records: <dns.resolver.Answer object at 0x000001D2D04CABD0>
# A records: <dns.resolver.Answer object at 0x000001D2D048E850>
# A records: <dns.resolver.Answer object at 0x000001D2D053AA90>
# A records: <dns.resolver.Answer object at 0x000001D2D053B610>
# A records: <dns.resolver.Answer object at 0x000001D2CFB58ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D053AA90>
# A records: <dns.resolver.Answer object at 0x000001D2D053B610>
# A records: <dns.resolver.Answer object at 0x000001D2D02F9D90>
# A records: <dns.resolver.Answer object at 0x000001D2D048D590>
# A records: <dns.resolver.Answer object at 0x000001D2D04F23D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0163A10>
# A records: <dns.resolver.Answer object at 0x000001D2CBAA1E50>
# A records: <dns.resolver.Answer object at 0x000001D2D03EC150>
# A records: <dns.resolver.Answer object at 0x000001D2D03EDFD0>
# A records: <dns.resolver.Answer object at 0x000001D2D053B710>
# A records: <dns.resolver.Answer object at 0x000001D2D053A510>
# A records: <dns.resolver.Answer object at 0x000001D2D03EC5D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04CABD0>
# A records: <dns.resolver.Answer object at 0x000001D2D03EDFD0>
# A records: <dns.resolver.Answer object at 0x000001D2CBAA1E50>
# A records: <dns.resolver.Answer object at 0x000001D2D03EDFD0>
# A records: <dns.resolver.Answer object at 0x000001D2D053B850>
# A records: <dns.resolver.Answer object at 0x000001D2CD89B750>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC150>
# A records: <dns.resolver.Answer object at 0x000001D2D0452450>
# A records: <dns.resolver.Answer object at 0x000001D2D03EDFD0>
# A records: <dns.resolver.Answer object at 0x000001D2D03EC5D0>
# A records: <dns.resolver.Answer object at 0x000001D2D03EDFD0>
# A records: <dns.resolver.Answer object at 0x000001D2D0183310>
# A records: <dns.resolver.Answer object at 0x000001D2D0182ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D0539E10>
# A records: <dns.resolver.Answer object at 0x000001D2CB0C9290>
# A records: <dns.resolver.Answer object at 0x000001D2CD89B750>
# A records: <dns.resolver.Answer object at 0x000001D2D0240990>
# A records: <dns.resolver.Answer object at 0x000001D2D03ED2D0>
# A records: <dns.resolver.Answer object at 0x000001D2D03EDF50>
# A records: <dns.resolver.Answer object at 0x000001D2D03EE750>
# A records: <dns.resolver.Answer object at 0x000001D2D03ECD50>
# A records: <dns.resolver.Answer object at 0x000001D2D03ED2D0>
# A records: <dns.resolver.Answer object at 0x000001D2D03EE750>
# A records: <dns.resolver.Answer object at 0x000001D2D03ECF50>
# A records: <dns.resolver.Answer object at 0x000001D2D03EE090>
# A records: <dns.resolver.Answer object at 0x000001D2D03EF750>
# A records: <dns.resolver.Answer object at 0x000001D2CBE04E50>
# A records: <dns.resolver.Answer object at 0x000001D2D03ECE50>
# A records: <dns.resolver.Answer object at 0x000001D2D03EF6D0>
# A records: <dns.resolver.Answer object at 0x000001D2D03ECF50>
# A records: <dns.resolver.Answer object at 0x000001D2D048EF50>
# A records: <dns.resolver.Answer object at 0x000001D2D03EF6D0>
# A records: <dns.resolver.Answer object at 0x000001D2B4F812D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0373750>
# A records: <dns.resolver.Answer object at 0x000001D2D04CBBD0>
# A records: <dns.resolver.Answer object at 0x000001D2D04CAB90>
# A records: <dns.resolver.Answer object at 0x000001D2D0240990>
# A records: <dns.resolver.Answer object at 0x000001D2CB0C9290>
# A records: <dns.resolver.Answer object at 0x000001D2CB762ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D0240290>
# A records: <dns.resolver.Answer object at 0x000001D2D03ECE50>
# A records: <dns.resolver.Answer object at 0x000001D2D0453150>
# A records: <dns.resolver.Answer object at 0x000001D2D02F9D90>
# A records: <dns.resolver.Answer object at 0x000001D2CB762ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D0452450>
# A records: <dns.resolver.Answer object at 0x000001D2D0346F90>
# A records: <dns.resolver.Answer object at 0x000001D2D04CB510>
# A records: <dns.resolver.Answer object at 0x000001D2D01276D0>
# A records: <dns.resolver.Answer object at 0x000001D2B4F411D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0453150>
# A records: <dns.resolver.Answer object at 0x000001D2D04F2190>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1DD0>
# A records: <dns.resolver.Answer object at 0x000001D2D03ECE50>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3810>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1590>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE3D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FFD90>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE590>
# A records: <dns.resolver.Answer object at 0x000001D2D04FEE90>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE850>
# A records: <dns.resolver.Answer object at 0x000001D2D04FDD10>
# A records: <dns.resolver.Answer object at 0x000001D2D04FFF10>
# A records: <dns.resolver.Answer object at 0x000001D2D04FCA50>
# A records: <dns.resolver.Answer object at 0x000001D2D04FDC50>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC990>
# A records: <dns.resolver.Answer object at 0x000001D2D04FDB90>
# A records: <dns.resolver.Answer object at 0x000001D2D0301150>
# A records: <dns.resolver.Answer object at 0x000001D2D0346F90>
# A records: <dns.resolver.Answer object at 0x000001D2CB762ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE510>
# A records: <dns.resolver.Answer object at 0x000001D2D04FF610>
# A records: <dns.resolver.Answer object at 0x000001D2D04FF610>
# A records: <dns.resolver.Answer object at 0x000001D2D048EF50>
# A records: <dns.resolver.Answer object at 0x000001D2CD8A21D0>
# A records: <dns.resolver.Answer object at 0x000001D2D048EF50>
# A records: <dns.resolver.Answer object at 0x000001D2CDD5FE90>
# A records: <dns.resolver.Answer object at 0x000001D2D0346F90>
# A records: <dns.resolver.Answer object at 0x000001D2D03017D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1590>
# A records: <dns.resolver.Answer object at 0x000001D2D03ECE50>
# A records: <dns.resolver.Answer object at 0x000001D2CD6B7690>
# A records: <dns.resolver.Answer object at 0x000001D2B4F59810>
# A records: <dns.resolver.Answer object at 0x000001D2CD8A21D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0346F90>
# A records: <dns.resolver.Answer object at 0x000001D2D0301150>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC550>
# A records: <dns.resolver.Answer object at 0x000001D2CBAA1E50>
# A records: <dns.resolver.Answer object at 0x000001D2D01276D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1DD0>
# A records: <dns.resolver.Answer object at 0x000001D2D0373750>
# A records: <dns.resolver.Answer object at 0x000001D2D0253150>
# A records: <dns.resolver.Answer object at 0x000001D2D04CAB90>
# A records: <dns.resolver.Answer object at 0x000001D2D048C610>
# A records: <dns.resolver.Answer object at 0x000001D2B4F59810>
# A records: <dns.resolver.Answer object at 0x000001D2D0539850>
# A records: <dns.resolver.Answer object at 0x000001D2CD89B750>
# A records: <dns.resolver.Answer object at 0x000001D2D053B090>
# A records: <dns.resolver.Answer object at 0x000001D2D02F9D90>
# A records: <dns.resolver.Answer object at 0x000001D2D04CB510>
# A records: <dns.resolver.Answer object at 0x000001D2D052BA90>
# A records: <dns.resolver.Answer object at 0x000001D2D0529490>
# A records: <dns.resolver.Answer object at 0x000001D2D0528D50>
# A records: <dns.resolver.Answer object at 0x000001D2D052AAD0>
# A records: <dns.resolver.Answer object at 0x000001D2D0529850>
# A records: <dns.resolver.Answer object at 0x000001D2D052BD90>
# A records: <dns.resolver.Answer object at 0x000001D2D052B110>
# A records: <dns.resolver.Answer object at 0x000001D2D05295D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0529B50>
# ...
# A records: <dns.resolver.Answer object at 0x000001D2D052BE10>
# A records: <dns.resolver.Answer object at 0x000001D2D0457D90>
# A records: <dns.resolver.Answer object at 0x000001D2D0529D10>
# A records: <dns.resolver.Answer object at 0x000001D2D052BFD0>
# A records: <dns.resolver.Answer object at 0x000001D2D0528DD0>
# A records: <dns.resolver.Answer object at 0x000001D2D04C8ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D052AA10>
# A records: <dns.resolver.Answer object at 0x000001D2CD826890>
# A records: <dns.resolver.Answer object at 0x000001D2D0528110>
# A records: <dns.resolver.Answer object at 0x000001D2D052A4D0>
# A records: <dns.resolver.Answer object at 0x000001D2D052A4D0>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D0528050>
# A records: <dns.resolver.Answer object at 0x000001D2D013F510>
# A records: <dns.resolver.Answer object at 0x000001D2D04B5410>
# A records: <dns.resolver.Answer object at 0x000001D2D05282D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04B4190>
# No A records
# No AAAA records
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D052A4D0>
# A records: <dns.resolver.Answer object at 0x000001D2D048C3D0>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D0240990>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D04F23D0>
# A records: <dns.resolver.Answer object at 0x000001D2D013F510>
# A records: <dns.resolver.Answer object at 0x000001D2D053AB50>
# A records: <dns.resolver.Answer object at 0x000001D2D053A710>
# A records: <dns.resolver.Answer object at 0x000001D2D053AB50>
# A records: <dns.resolver.Answer object at 0x000001D2D0240990>
# A records: <dns.resolver.Answer object at 0x000001D2D053AB50>
# A records: <dns.resolver.Answer object at 0x000001D2D04C8650>
# A records: <dns.resolver.Answer object at 0x000001D2D0451E10>
# A records: <dns.resolver.Answer object at 0x000001D2CB762ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D0528CD0>
# A records: <dns.resolver.Answer object at 0x000001D2D053A050>
# A records: <dns.resolver.Answer object at 0x000001D2D053A050>
# A records: <dns.resolver.Answer object at 0x000001D2CB78D990>
# A records: <dns.resolver.Answer object at 0x000001D2D0528E90>
# A records: <dns.resolver.Answer object at 0x000001D2CD89B710>
# A records: <dns.resolver.Answer object at 0x000001D2CD8B3890>
# A records: <dns.resolver.Answer object at 0x000001D2CD89B710>
# A records: <dns.resolver.Answer object at 0x000001D2D0538810>
# A records: <dns.resolver.Answer object at 0x000001D2CD71F390>
# A records: <dns.resolver.Answer object at 0x000001D2D04C8B10>
# A records: <dns.resolver.Answer object at 0x000001D2CD89B5D0>
# No A records
# No AAAA records
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2CDD5FE90>
# A records: <dns.resolver.Answer object at 0x000001D2D0504710>
# A records: <dns.resolver.Answer object at 0x000001D2D0504B10>
# A records: <dns.resolver.Answer object at 0x000001D2D0240990>
# A records: <dns.resolver.Answer object at 0x000001D2D0240E10>
# A records: <dns.resolver.Answer object at 0x000001D2D0539650>
# No A records
# No AAAA records
# No A records
# No AAAA records
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D04FC150>
# A records: <dns.resolver.Answer object at 0x000001D2CDD60850>
# A records: <dns.resolver.Answer object at 0x000001D2D0450290>
# No A records
# No AAAA records
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2CF8AFED0>
# A records: <dns.resolver.Answer object at 0x000001D2D03EE690>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D04F3510>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D0539990>
# A records: <dns.resolver.Answer object at 0x000001D2D04FF390>
# A records: <dns.resolver.Answer object at 0x000001D2D052ADD0>
# A records: <dns.resolver.Answer object at 0x000001D2D052B950>
# A records: <dns.resolver.Answer object at 0x000001D2D0528C10>
# A records: <dns.resolver.Answer object at 0x000001D2D052A410>
# A records: <dns.resolver.Answer object at 0x000001D2D0165050>
# A records: <dns.resolver.Answer object at 0x000001D2D04563D0>
# A records: <dns.resolver.Answer object at 0x000001D2B4F44A50>
# A records: <dns.resolver.Answer object at 0x000001D2D0240990>
# A records: <dns.resolver.Answer object at 0x000001D2D04FF390>
# A records: <dns.resolver.Answer object at 0x000001D2D0528C10>
# A records: <dns.resolver.Answer object at 0x000001D2D052A990>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D0302050>
# A records: <dns.resolver.Answer object at 0x000001D2D052BE10>
# A records: <dns.resolver.Answer object at 0x000001D2D04CAC50>
# A records: <dns.resolver.Answer object at 0x000001D2D04C95D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04CAC50>
# A records: <dns.resolver.Answer object at 0x000001D2D0508B10>
# A records: <dns.resolver.Answer object at 0x000001D2D0509710>
# A records: <dns.resolver.Answer object at 0x000001D2CD89B710>
# A records: <dns.resolver.Answer object at 0x000001D2D0508F90>
# A records: <dns.resolver.Answer object at 0x000001D2D0508850>
# A records: <dns.resolver.Answer object at 0x000001D2D0508890>
# A records: <dns.resolver.Answer object at 0x000001D2D050A2D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0509050>
# A records: <dns.resolver.Answer object at 0x000001D2D0508B10>
# No A records
# No AAAA records
# No A records
# No AAAA records
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D013F510>
# A records: <dns.resolver.Answer object at 0x000001D2D0240990>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D052BE10>
# A records: <dns.resolver.Answer object at 0x000001D2D013D410>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D04F0F50>
# A records: <dns.resolver.Answer object at 0x000001D2D04B5D90>
# A records: <dns.resolver.Answer object at 0x000001D2D04B62D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04B5090>
# A records: <dns.resolver.Answer object at 0x000001D2D04FEF90>
# A records: <dns.resolver.Answer object at 0x000001D2D04B4DD0>
# A records: <dns.resolver.Answer object at 0x000001D2CD89B710>
# A records: <dns.resolver.Answer object at 0x000001D2D053A990>
# A records: <dns.resolver.Answer object at 0x000001D2D04B4DD0>
# A records: <dns.resolver.Answer object at 0x000001D2D03FE350>
# A records: <dns.resolver.Answer object at 0x000001D2D053A050>
# A records: <dns.resolver.Answer object at 0x000001D2CDD63B50>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE590>
# A records: <dns.resolver.Answer object at 0x000001D2D04C9210>
# A records: <dns.resolver.Answer object at 0x000001D2D050BE10>
# A records: <dns.resolver.Answer object at 0x000001D2CDD63B50>
# A records: <dns.resolver.Answer object at 0x000001D2D048F550>
# A records: <dns.resolver.Answer object at 0x000001D2D053A050>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3390>
# A records: <dns.resolver.Answer object at 0x000001D2D053A050>
# A records: <dns.resolver.Answer object at 0x000001D2D03ED550>
# A records: <dns.resolver.Answer object at 0x000001D2D048C610>
# A records: <dns.resolver.Answer object at 0x000001D2D053BF10>
# A records: <dns.resolver.Answer object at 0x000001D2D0505890>
# A records: <dns.resolver.Answer object at 0x000001D2D013F510>
# A records: <dns.resolver.Answer object at 0x000001D2D0243C10>
# A records: <dns.resolver.Answer object at 0x000001D2D04B7990>
# A records: <dns.resolver.Answer object at 0x000001D2D04FCA50>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3550>
# A records: <dns.resolver.Answer object at 0x000001D2B4F53A90>
# A records: <dns.resolver.Answer object at 0x000001D2D03FF2D0>
# A records: <dns.resolver.Answer object at 0x000001D2D03FF2D0>
# A records: <dns.resolver.Answer object at 0x000001D2CD7D7E10>
# A records: <dns.resolver.Answer object at 0x000001D2D0509F90>
# A records: <dns.resolver.Answer object at 0x000001D2B4F882D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0509510>
# A records: <dns.resolver.Answer object at 0x000001D2D03FF2D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0182ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D04C95D0>
# A records: <dns.resolver.Answer object at 0x000001D2CD89AF90>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D0528650>
# A records: <dns.resolver.Answer object at 0x000001D2D052B650>
# A records: <dns.resolver.Answer object at 0x000001D2D0528DD0>
# A records: <dns.resolver.Answer object at 0x000001D2CD89AF90>
# A records: <dns.resolver.Answer object at 0x000001D2D05293D0>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D04563D0>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D021B750>
# A records: <dns.resolver.Answer object at 0x000001D2CD89AF90>
# A records: <dns.resolver.Answer object at 0x000001D2D048C3D0>
# A records: <dns.resolver.Answer object at 0x000001D2D050B090>
# A records: <dns.resolver.Answer object at 0x000001D2D0509ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3690>
# A records: <dns.resolver.Answer object at 0x000001D2D050B090>
# A records: <dns.resolver.Answer object at 0x000001D2D0509D50>
# A records: <dns.resolver.Answer object at 0x000001D2D0528110>
# A records: <dns.resolver.Answer object at 0x000001D2D052BFD0>
# A records: <dns.resolver.Answer object at 0x000001D2CD89AF90>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1410>
# A records: <dns.resolver.Answer object at 0x000001D2D0127A50>
# A records: <dns.resolver.Answer object at 0x000001D2D048C150>
# A records: <dns.resolver.Answer object at 0x000001D2D04F2210>
# A records: <dns.resolver.Answer object at 0x000001D2D04B5510>
# A records: <dns.resolver.Answer object at 0x000001D2D04B4210>
# A records: <dns.resolver.Answer object at 0x000001D2D04B7E50>
# A records: <dns.resolver.Answer object at 0x000001D2CD7D7E10>
# A records: <dns.resolver.Answer object at 0x000001D2D0450290>
# A records: <dns.resolver.Answer object at 0x000001D2D050A050>
# A records: <dns.resolver.Answer object at 0x000001D2D04F2210>
# A records: <dns.resolver.Answer object at 0x000001D2CD826890>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D03ECE50>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3690>
# A records: <dns.resolver.Answer object at 0x000001D2D04F2A90>
# A records: <dns.resolver.Answer object at 0x000001D2D04B4210>
# A records: <dns.resolver.Answer object at 0x000001D2D04F2A90>
# A records: <dns.resolver.Answer object at 0x000001D2D04F09D0>
# A records: <dns.resolver.Answer object at 0x000001D2D053A090>
# A records: <dns.resolver.Answer object at 0x000001D2D0539210>
# A records: <dns.resolver.Answer object at 0x000001D2D050B090>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1690>
# A records: <dns.resolver.Answer object at 0x000001D2D0538E10>
# A records: <dns.resolver.Answer object at 0x000001D2D05387D0>
# No A records
# No AAAA records
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D03ECE50>
# A records: <dns.resolver.Answer object at 0x000001D2D05394D0>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D050A050>
# A records: <dns.resolver.Answer object at 0x000001D2D050B2D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FEFD0>
# A records: <dns.resolver.Answer object at 0x000001D2D0529B50>
# A records: <dns.resolver.Answer object at 0x000001D2D04FDBD0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FDA10>
# A records: <dns.resolver.Answer object at 0x000001D2D04FDBD0>
# A records: <dns.resolver.Answer object at 0x000001D2D04F3690>
# A records: <dns.resolver.Answer object at 0x000001D2CDD5D790>
# A records: <dns.resolver.Answer object at 0x000001D2D050B2D0>
# A records: <dns.resolver.Answer object at 0x000001D2D050A3D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0507A50>
# A records: <dns.resolver.Answer object at 0x000001D2D0507CD0>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1690>
# A records: <dns.resolver.Answer object at 0x000001D2D0504050>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D0182ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D0504350>
# A records: <dns.resolver.Answer object at 0x000001D2D03EE350>
# A records: <dns.resolver.Answer object at 0x000001D2D0506050>
# A records: <dns.resolver.Answer object at 0x000001D2D05046D0>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D0506850>
# A records: <dns.resolver.Answer object at 0x000001D2D0507F90>
# A records: <dns.resolver.Answer object at 0x000001D2D0507C90>
# A records: <dns.resolver.Answer object at 0x000001D2CD7D7E10>
# A records: <dns.resolver.Answer object at 0x000001D2D04FFD90>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC750>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE590>
# A records: <dns.resolver.Answer object at 0x000001D2D04FC750>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE010>
# A records: <dns.resolver.Answer object at 0x000001D2CD89AF90>
# A records: <dns.resolver.Answer object at 0x000001D2D053AB10>
# A records: <dns.resolver.Answer object at 0x000001D2D053BE50>
# A records: <dns.resolver.Answer object at 0x000001D2D0538F50>
# A records: <dns.resolver.Answer object at 0x000001D2D05386D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0538110>
# A records: <dns.resolver.Answer object at 0x000001D2CD826890>
# A records: <dns.resolver.Answer object at 0x000001D2D02AED90>
# A records: <dns.resolver.Answer object at 0x000001D2CF8AFED0>
# A records: <dns.resolver.Answer object at 0x000001D2D0127A50>
# A records: <dns.resolver.Answer object at 0x000001D2D046F510>
# A records: <dns.resolver.Answer object at 0x000001D2D0451E10>
# A records: <dns.resolver.Answer object at 0x000001D2D0182ED0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE6D0>
# A records: <dns.resolver.Answer object at 0x000001D2D0538990>
# A records: <dns.resolver.Answer object at 0x000001D2CD89B5D0>
# A records: <dns.resolver.Answer object at 0x000001D2CD89AF90>
# A records: <dns.resolver.Answer object at 0x000001D2D048D390>
# A records: <dns.resolver.Answer object at 0x000001D2B4F53A90>
# A records: <dns.resolver.Answer object at 0x000001D2CDD60490>
# A records: <dns.resolver.Answer object at 0x000001D2D04F1F50>
# A records: <dns.resolver.Answer object at 0x000001D2D04F09D0>
# A records: <dns.resolver.Answer object at 0x000001D2D03ECF50>
# A records: <dns.resolver.Answer object at 0x000001D2D03EE690>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE1D0>
# A records: <dns.resolver.Answer object at 0x000001D2D03ECF50>
# A records: <dns.resolver.Answer object at 0x000001D2D04FF750>
# A records: <dns.resolver.Answer object at 0x000001D2D0451F50>
# A records: <dns.resolver.Answer object at 0x000001D2D03EE690>
# A records: <dns.resolver.Answer object at 0x000001D2D016EC90>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE010>
# A records: <dns.resolver.Answer object at 0x000001D2D052A450>
# A records: <dns.resolver.Answer object at 0x000001D2D052ADD0>
# A records: <dns.resolver.Answer object at 0x000001D2D052ADD0>
# A records: <dns.resolver.Answer object at 0x000001D2D052ADD0>
# A records: <dns.resolver.Answer object at 0x000001D2D052ADD0>
# No A records
# No AAAA records
# A records: <dns.resolver.Answer object at 0x000001D2D052AF90>
# A records: <dns.resolver.Answer object at 0x000001D2D04B7890>
# A records: <dns.resolver.Answer object at 0x000001D2D04B5A90>
# A records: <dns.resolver.Answer object at 0x000001D2D04B5F50>
# A records: <dns.resolver.Answer object at 0x000001D2D04B4510>
# A records: <dns.resolver.Answer object at 0x000001D2D04B6CD0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FE1D0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FEFD0>
# A records: <dns.resolver.Answer object at 0x000001D2D04FFED0>
# 0      -1
# 1       1
# 2       1
# 3      -1
# 4      -1
#        ..
# 2473    1
# 2474    1
# 2475    1
# 2476    1
# 2477    1
# Name: website_url, Length: 2478, dtype: int64

# %%
df_phish['url_length'] = df_phish['website_url'].apply(is_url_long)
df_phish['shortining_service'] = df_phish['website_url'].apply(is_shortening_service)
